# %% [markdown]
# ### Github
# https://github.com/minji-o-j/Deep-Learning

# %% [markdown]
# ## Load packages

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### MNIST train, test dataset 가져오기

# %%
#"": 현재 폴더에 MNIST 있음
mnist_train=dset.MNIST("",train=True,transform=transforms.ToTensor(), target_transform=None, download=True) ##Train용
mnist_test=dset.MNIST("",train=False, transform=transforms.ToTensor(),target_transform=None,download=True) ##Test용

# %% [markdown]
# ### 대략적인 데이터 형태

# %%
print "mnist_train 길이:", len(mnist_train)
print "mnist_test 길이:", len(mnist_test)

#데이터 하나 형태
image, label=mnist_train.__getitem__(0)
print "image data 형태:", image.size()
print "label: ", label

#그리기
img=image.numpy() #image 타입을 numpy로 변환(1,28,28)
plt.title("label: %d" %label)
plt.imshow(img[0],cmap='gray')
plt.show()
# Out:
# mnist_train 길이: 60000
# mnist_test 길이: 10000
# image data 형태: torch.Size([1, 28, 28])
# label:  5

# %% [markdown]
# ### MNIST data 띄워보기

# %%
print(mnist_train[0][1])  # label
print(mnist_train[0][0].size())  # image

for i in range(3):
    img= mnist_train[i][0].numpy()
    print(mnist_train[i][1])
    plt.imshow(img[0], cmap='gray')
    plt.show()
# Out:
# 5
# torch.Size([1, 28, 28])
# 5
# 0
# 4

# %% [markdown]
# ### convolution 하나 씌워보기

# %%
#mnist 의 첫 번째 이미지, 라벨 가져오기
image, label= mnist_train[0]
# view: tensor 의 사이즈 조절. -1 :해당 차원 확장시켜라
# [1, 28, 28] -> [1, 1, 28, 28] 채널, h, w -->batch_size, 채널, h, w
image= image.view(-1, image.size()[0], image.size()[1], image.size()[2])
print(image.size())

print label

# convolutional filter 정의
conv_layer= nn.Conv2d(in_channels=1, out_channels= 3, kernel_size= 3, padding= 1)
# image에 filter 적용
output= conv_layer(Variable(image))
print(output.size())

for i in range(3):
    plt.imshow(output[0,i,:,:].data.numpy(), cmap= 'gray')
    plt.show()
# Out:
# torch.Size([1, 1, 28, 28])
# 5
# torch.Size([1, 3, 28, 28])

# %% [markdown]
# ## CNN 만들기
# ### train, test data 가져오기

# %%
import numpy as np
import torch.optim as optim

batch_size= 16
learning_rate= 0.0002
num_epoch= 100 # 1000

# %%
# 후에 학습시킬 때 batch_size 단위로 학습시켜나감
train_loader= torch.utils.data.DataLoader(list(mnist_train)[:batch_size*100], batch_size= batch_size, #mnist_train을 train
                                         shuffle= True, num_workers=2,
                                         drop_last= True)  # batch_szie 만큼 나눌 때 나머지는 버려라
test_loader= torch.utils.data.DataLoader((mnist_test), batch_size= batch_size,
                                         shuffle= False, num_workers=2,
                                         drop_last= True)

# %% [markdown]
# ## CNN 클래스 만들기(모델 만들기)

# %%
class CNN(nn.Module):  # nn.Module 상속받음
    def __init__(self):
        super(CNN, self).__init__()  # 28x28
        self.layer= nn.Sequential(
            nn.Conv2d(1, 16, 5, padding= 2),
            nn.ReLU(),
        
            nn.Conv2d(16, 32, 5, padding= 2),  # 28x28
            nn.ReLU(),
            nn.MaxPool2d(2,2),  # 28x28 -> 14x14
        
            nn.Conv2d(32, 64, 5, padding= 2),  # 14x14
            nn.ReLU(),
            nn.MaxPool2d(2,2)  # 14x14 -> 7x7
        )
        self.fc_layer= nn.Sequential(
            nn.Linear(64*7*7, 100),
            nn.ReLU(),
            nn.Linear(100, 10)
        )
        
    def forward(self, x):
        out= self.layer(x)
        out= out.view(batch_size, -1)
        out= self.fc_layer(out)
        return out
    
model= CNN()  #.cuda() #gpu에서만

# %%
# 파라미터 체크하기
for parameter in model.parameters():
    #print(parameter)
    print(parameter.shape)
# Out:
# torch.Size([16, 1, 5, 5])
# torch.Size([16])
# torch.Size([32, 16, 5, 5])
# torch.Size([32])
# torch.Size([64, 32, 5, 5])
# torch.Size([64])
# torch.Size([100, 3136])
# torch.Size([100])
# torch.Size([10, 100])
# torch.Size([10])

# %%
# loss function, optimizer 선언
loss_func= nn.CrossEntropyLoss()#분류
optimizer= torch.optim.Adam(model.parameters(), lr= learning_rate)

# %% [markdown]
# ### optimization

# %%
for i in range(num_epoch):
    for j, [image, label] in enumerate(train_loader): # batch_size 만큼
        x= Variable(image)  # .cuda()
        y_= Variable(label)  # .cuda()
        
        optimizer.zero_grad()  # optimizer 안에서 이전 gradient 들을 초기화
        output= model.forward(x)
        loss= loss_func(output, y_)#예측값, 정답
        loss.backward()  # gradient 계산
        optimizer.step()  # parameter 업데이트
        
        if j%50==0:
            print(loss, j, i)
# Out:
# (tensor(2.3130, grad_fn=<NllLossBackward>), 0, 0)
# (tensor(1.6788, grad_fn=<NllLossBackward>), 50, 0)
# (tensor(0.6701, grad_fn=<NllLossBackward>), 0, 1)
# (tensor(0.3844, grad_fn=<NllLossBackward>), 50, 1)
# (tensor(0.1893, grad_fn=<NllLossBackward>), 0, 2)
# (tensor(0.3737, grad_fn=<NllLossBackward>), 50, 2)
# (tensor(0.1532, grad_fn=<NllLossBackward>), 0, 3)
# (tensor(0.1526, grad_fn=<NllLossBackward>), 50, 3)
# (tensor(0.1125, grad_fn=<NllLossBackward>), 0, 4)
# (tensor(0.3541, grad_fn=<NllLossBackward>), 50, 4)
# (tensor(0.0136, grad_fn=<NllLossBackward>), 0, 5)
# (tensor(0.0311, grad_fn=<NllLossBackward>), 50, 5)
# (tensor(0.1501, grad_fn=<NllLossBackward>), 0, 6)
# (tensor(0.0397, grad_fn=<NllLossBackward>), 50, 6)
# (tensor(0.0298, grad_fn=<NllLossBackward>), 0, 7)
# (tensor(0.0329, grad_fn=<NllLossBackward>), 50, 7)
# (tensor(0.0234, grad_fn=<NllLossBackward>), 0, 8)
# (tensor(0.0225, grad_fn=<NllLossBackward>), 50, 8)
# (tensor(0.0528, grad_fn=<NllLossBackward>), 0, 9)
# (tensor(0.0147, grad_fn=<NllLossBackward>), 50, 9)
# (tensor(0.0113, grad_fn=<NllLossBackward>), 0, 10)
# (tensor(0.0469, grad_fn=<NllLossBackward>), 50, 10)
# (tensor(0.0494, grad_fn=<NllLossBackward>), 0, 11)
# (tensor(0.0605, grad_fn=<NllLossBackward>), 50, 11)
# (tensor(0.0111, grad_fn=<NllLossBackward>), 0, 12)
# (tensor(0.0024, grad_fn=<NllLossBackward>), 50, 12)
# (tensor(0.0049, grad_fn=<NllLossBackward>), 0, 13)
# (tensor(0.0008, grad_fn=<NllLossBackward>), 50, 13)
# (tensor(0.0065, grad_fn=<NllLossBackward>), 0, 14)
# (tensor(0.0016, grad_fn=<NllLossBackward>), 50, 14)
# (tensor(0.0005, grad_fn=<NllLossBackward>), 0, 15)
# (tensor(0.0041, grad_fn=<NllLossBackward>), 50, 15)
# (tensor(0.0005, grad_fn=<NllLossBackward>), 0, 16)
# (tensor(0.0003, grad_fn=<NllLossBackward>), 50, 16)
# (tensor(0.0009, grad_fn=<NllLossBackward>), 0, 17)
# (tensor(0.0004, grad_fn=<NllLossBackward>), 50, 17)
# (tensor(0.0027, grad_fn=<NllLossBackward>), 0, 18)
# (tensor(0.0026, grad_fn=<NllLossBackward>), 50, 18)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 0, 19)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 50, 19)
# (tensor(0.0004, grad_fn=<NllLossBackward>), 0, 20)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 50, 20)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 21)
# (tensor(0.0012, grad_fn=<NllLossBackward>), 50, 21)
# (tensor(0.0006, grad_fn=<NllLossBackward>), 0, 22)
# (tensor(0.0023, grad_fn=<NllLossBackward>), 50, 22)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 23)
# (tensor(0.0024, grad_fn=<NllLossBackward>), 50, 23)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 24)
# (tensor(0.0006, grad_fn=<NllLossBackward>), 50, 24)
# (tensor(0.0004, grad_fn=<NllLossBackward>), 0, 25)
# (tensor(9.0455e-05, grad_fn=<NllLossBackward>), 50, 25)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 26)
# (tensor(0.0012, grad_fn=<NllLossBackward>), 50, 26)
# (tensor(0.0004, grad_fn=<NllLossBackward>), 0, 27)
# (tensor(4.9155e-05, grad_fn=<NllLossBackward>), 50, 27)
# (tensor(0.0003, grad_fn=<NllLossBackward>), 0, 28)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 50, 28)
# (tensor(0.0004, grad_fn=<NllLossBackward>), 0, 29)
# (tensor(0.0010, grad_fn=<NllLossBackward>), 50, 29)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 0, 30)
# (tensor(0.0006, grad_fn=<NllLossBackward>), 50, 30)
# (tensor(4.4330e-05, grad_fn=<NllLossBackward>), 0, 31)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 50, 31)
# (tensor(0.0003, grad_fn=<NllLossBackward>), 0, 32)
# (tensor(6.7691e-05, grad_fn=<NllLossBackward>), 50, 32)
# (tensor(7.9281e-05, grad_fn=<NllLossBackward>), 0, 33)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 50, 33)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 34)
# (tensor(0.0005, grad_fn=<NllLossBackward>), 50, 34)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 35)
# (tensor(0.0003, grad_fn=<NllLossBackward>), 50, 35)
# (tensor(0.0004, grad_fn=<NllLossBackward>), 0, 36)
# (tensor(4.8757e-05, grad_fn=<NllLossBackward>), 50, 36)
# (tensor(1.8201e-05, grad_fn=<NllLossBackward>), 0, 37)
# (tensor(8.1581e-05, grad_fn=<NllLossBackward>), 50, 37)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 0, 38)
# (tensor(9.4917e-06, grad_fn=<NllLossBackward>), 50, 38)
# (tensor(5.6427e-05, grad_fn=<NllLossBackward>), 0, 39)
# (tensor(8.0466e-07, grad_fn=<NllLossBackward>), 50, 39)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 40)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 50, 40)
# (tensor(2.6693e-05, grad_fn=<NllLossBackward>), 0, 41)
# (tensor(0.0003, grad_fn=<NllLossBackward>), 50, 41)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 0, 42)
# (tensor(7.1090e-05, grad_fn=<NllLossBackward>), 50, 42)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 0, 43)
# (tensor(2.2105e-05, grad_fn=<NllLossBackward>), 50, 43)
# (tensor(6.3477e-06, grad_fn=<NllLossBackward>), 0, 44)
# (tensor(1.0803e-06, grad_fn=<NllLossBackward>), 50, 44)
# (tensor(2.4889e-05, grad_fn=<NllLossBackward>), 0, 45)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 50, 45)
# (tensor(3.3206e-05, grad_fn=<NllLossBackward>), 0, 46)
# (tensor(2.7004e-05, grad_fn=<NllLossBackward>), 50, 46)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 47)
# (tensor(6.9963e-05, grad_fn=<NllLossBackward>), 50, 47)
# (tensor(2.1121e-05, grad_fn=<NllLossBackward>), 0, 48)
# (tensor(7.3720e-05, grad_fn=<NllLossBackward>), 50, 48)
# (tensor(2.7630e-05, grad_fn=<NllLossBackward>), 0, 49)
# (tensor(2.5837e-05, grad_fn=<NllLossBackward>), 50, 49)
# (tensor(3.0503e-05, grad_fn=<NllLossBackward>), 0, 50)
# (tensor(0.0001, grad_fn=<NllLossBackward>), 50, 50)
# (tensor(4.4152e-05, grad_fn=<NllLossBackward>), 0, 51)
# (tensor(2.0524e-05, grad_fn=<NllLossBackward>), 50, 51)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 0, 52)
# (tensor(4.3775e-05, grad_fn=<NllLossBackward>), 50, 52)
# (tensor(5.4695e-05, grad_fn=<NllLossBackward>), 0, 53)
# (tensor(1.2219e-05, grad_fn=<NllLossBackward>), 50, 53)
# (tensor(7.6252e-05, grad_fn=<NllLossBackward>), 0, 54)
# (tensor(0.0002, grad_fn=<NllLossBackward>), 50, 54)
# (tensor(1.1689e-05, grad_fn=<NllLossBackward>), 0, 55)
# (tensor(2.2128e-06, grad_fn=<NllLossBackward>), 50, 55)
# (tensor(2.9578e-06, grad_fn=<NllLossBackward>), 0, 56)
# (tensor(3.7253e-08, grad_fn=<NllLossBackward>), 50, 56)
# (tensor(1.3008e-05, grad_fn=<NllLossBackward>), 0, 57)
# (tensor(1.5079e-05, grad_fn=<NllLossBackward>), 50, 57)
# (tensor(2.0673e-05, grad_fn=<NllLossBackward>), 0, 58)
# (tensor(1.2732e-05, grad_fn=<NllLossBackward>), 50, 58)
# (tensor(3.2519e-05, grad_fn=<NllLossBackward>), 0, 59)
# (tensor(4.1940e-05, grad_fn=<NllLossBackward>), 50, 59)
# (tensor(7.1299e-05, grad_fn=<NllLossBackward>), 0, 60)
# (tensor(1.2785e-05, grad_fn=<NllLossBackward>), 50, 60)
# (tensor(2.1085e-06, grad_fn=<NllLossBackward>), 0, 61)
# (tensor(2.2088e-05, grad_fn=<NllLossBackward>), 50, 61)
# (tensor(4.4207e-05, grad_fn=<NllLossBackward>), 0, 62)
# (tensor(6.6729e-05, grad_fn=<NllLossBackward>), 50, 62)
# (tensor(1.7762e-05, grad_fn=<NllLossBackward>), 0, 63)
# (tensor(3.2558e-06, grad_fn=<NllLossBackward>), 50, 63)
# (tensor(5.5438e-05, grad_fn=<NllLossBackward>), 0, 64)
# (tensor(4.6425e-05, grad_fn=<NllLossBackward>), 50, 64)
# (tensor(2.9951e-06, grad_fn=<NllLossBackward>), 0, 65)
# (tensor(1.6971e-05, grad_fn=<NllLossBackward>), 50, 65)
# (tensor(1.1250e-06, grad_fn=<NllLossBackward>), 0, 66)
# (tensor(2.6113e-05, grad_fn=<NllLossBackward>), 50, 66)
# (tensor(3.5574e-05, grad_fn=<NllLossBackward>), 0, 67)
# (tensor(8.4115e-06, grad_fn=<NllLossBackward>), 50, 67)
# (tensor(1.1361e-05, grad_fn=<NllLossBackward>), 0, 68)
# (tensor(1.2568e-05, grad_fn=<NllLossBackward>), 50, 68)
# (tensor(2.6090e-05, grad_fn=<NllLossBackward>), 0, 69)
# (tensor(2.4963e-05, grad_fn=<NllLossBackward>), 50, 69)
# (tensor(3.4495e-06, grad_fn=<NllLossBackward>), 0, 70)
# (tensor(2.0927e-05, grad_fn=<NllLossBackward>), 50, 70)
# (tensor(6.0571e-06, grad_fn=<NllLossBackward>), 0, 71)
# (tensor(6.6435e-05, grad_fn=<NllLossBackward>), 50, 71)
# (tensor(8.8064e-06, grad_fn=<NllLossBackward>), 0, 72)
# (tensor(1.4900e-05, grad_fn=<NllLossBackward>), 50, 72)
# (tensor(4.6194e-07, grad_fn=<NllLossBackward>), 0, 73)
# (tensor(1.1973e-05, grad_fn=<NllLossBackward>), 50, 73)
# (tensor(3.4347e-06, grad_fn=<NllLossBackward>), 0, 74)
# (tensor(2.3841e-06, grad_fn=<NllLossBackward>), 50, 74)
# (tensor(2.3125e-05, grad_fn=<NllLossBackward>), 0, 75)
# (tensor(2.3572e-05, grad_fn=<NllLossBackward>), 50, 75)
# (tensor(4.5447e-06, grad_fn=<NllLossBackward>), 0, 76)
# (tensor(9.3132e-07, grad_fn=<NllLossBackward>), 50, 76)
# (tensor(2.5928e-06, grad_fn=<NllLossBackward>), 0, 77)
# (tensor(9.6857e-07, grad_fn=<NllLossBackward>), 50, 77)
# (tensor(3.5315e-06, grad_fn=<NllLossBackward>), 0, 78)
# (tensor(3.7252e-06, grad_fn=<NllLossBackward>), 50, 78)
# (tensor(2.7567e-06, grad_fn=<NllLossBackward>), 0, 79)
# (tensor(6.3700e-06, grad_fn=<NllLossBackward>), 50, 79)
# (tensor(8.3966e-06, grad_fn=<NllLossBackward>), 0, 80)
# (tensor(1.5705e-05, grad_fn=<NllLossBackward>), 50, 80)
# (tensor(6.5338e-06, grad_fn=<NllLossBackward>), 0, 81)
# (tensor(7.9721e-07, grad_fn=<NllLossBackward>), 50, 81)
# (tensor(9.1788e-06, grad_fn=<NllLossBackward>), 0, 82)
# (tensor(1.0020e-05, grad_fn=<NllLossBackward>), 50, 82)
# (tensor(1.4610e-05, grad_fn=<NllLossBackward>), 0, 83)
# (tensor(2.5629e-06, grad_fn=<NllLossBackward>), 50, 83)
# (tensor(1.9222e-06, grad_fn=<NllLossBackward>), 0, 84)
# (tensor(5.6696e-06, grad_fn=<NllLossBackward>), 50, 84)
# (tensor(9.2831e-06, grad_fn=<NllLossBackward>), 0, 85)
# (tensor(4.0978e-06, grad_fn=<NllLossBackward>), 50, 85)
# (tensor(9.2830e-06, grad_fn=<NllLossBackward>), 0, 86)
# (tensor(3.0398e-06, grad_fn=<NllLossBackward>), 50, 86)
# (tensor(5.0514e-06, grad_fn=<NllLossBackward>), 0, 87)
# (tensor(3.1441e-06, grad_fn=<NllLossBackward>), 50, 87)
# (tensor(1.1176e-07, grad_fn=<NllLossBackward>), 0, 88)
# (tensor(1.0729e-06, grad_fn=<NllLossBackward>), 50, 88)
# (tensor(3.6135e-06, grad_fn=<NllLossBackward>), 0, 89)
# (tensor(5.9902e-06, grad_fn=<NllLossBackward>), 50, 89)
# (tensor(4.1723e-07, grad_fn=<NllLossBackward>), 0, 90)
# (tensor(5.2154e-08, grad_fn=<NllLossBackward>), 50, 90)
# (tensor(8.4413e-06, grad_fn=<NllLossBackward>), 0, 91)
# (tensor(6.5191e-06, grad_fn=<NllLossBackward>), 50, 91)
# (tensor(1.8552e-06, grad_fn=<NllLossBackward>), 0, 92)
# (tensor(6.3925e-06, grad_fn=<NllLossBackward>), 50, 92)
# (tensor(4.4703e-08, grad_fn=<NllLossBackward>), 0, 93)
# (tensor(2.2575e-06, grad_fn=<NllLossBackward>), 50, 93)
# (tensor(1.0431e-07, grad_fn=<NllLossBackward>), 0, 94)
# (tensor(8.8734e-06, grad_fn=<NllLossBackward>), 50, 94)
# (tensor(2.4289e-06, grad_fn=<NllLossBackward>), 0, 95)
# (tensor(3.6508e-07, grad_fn=<NllLossBackward>), 50, 95)
# (tensor(3.4273e-07, grad_fn=<NllLossBackward>), 0, 96)
# (tensor(7.9568e-06, grad_fn=<NllLossBackward>), 50, 96)
# (tensor(5.1706e-06, grad_fn=<NllLossBackward>), 0, 97)
# (tensor(6.7055e-08, grad_fn=<NllLossBackward>), 50, 97)
# (tensor(3.3527e-06, grad_fn=<NllLossBackward>), 0, 98)
# (tensor(5.0365e-06, grad_fn=<NllLossBackward>), 50, 98)
# (tensor(4.6939e-07, grad_fn=<NllLossBackward>), 0, 99)
# (tensor(9.4622e-07, grad_fn=<NllLossBackward>), 50, 99)

# %%
# 모델 저장시키기
torch.save(model, 'nets/mycnn_model_%d.pkl'%(num_epoch))

# %%
## epoch=10
try:
    # 미리 학습시킨 네트워크의 파라미터 집합 [피클]이라 발음함.
    model=torch.load('nets/mycnn_model_10.pkl')
    print("model restored")
except:
    print("model not restored")
# Out:
# model restored

# %%
def ComputeAccr(dloader, imodel):
    correct= 0
    total= 0
    
    for j, [imgs, labels] in enumerate(dloader):  #batch_size 만큼
        img= Variable(imgs)  # .cuda() # x
        label= Variable(labels)  # y
        #label= Variable(labels).cuda()
        
        output= imodel.forward(img)  # forward prop.
        _, output_index= torch.max(output, 1)
        
        total += label.size(0)
        correct += (output_index == label).sum().float()
    print("Accuracy of Test Data: {}".format(100*correct/total))

# %%
#epoch=10
ComputeAccr(test_loader, model)
# Out:
# Accuracy of Test Data: 93.9700012207

# %%
## epoch=100
try:
    # 미리 학습시킨 네트워크의 파라미터 집합 [피클]이라 발음함.
    model2=torch.load('nets/mycnn_model_100.pkl')
    print("model restored")
except:
    print("model not restored")
# Out:
# model restored

# %%
#epoch=100
ComputeAccr(test_loader, model2)
# Out:
# Accuracy of Test Data: 95.6900024414
